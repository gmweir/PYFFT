# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as _np
import matplotlib.pyplot as _plt
import FFT as _fft

# %%
_fft.fft_analysis.test_fftpwelch(plotit=False, verbose=False)
# Out:
# ('tper', 0.026663411657003356)
# ('Fs', 81919.99999999999)
# ('nsig', 16383)
# ('nwins', 2184)
# ('noverlap', 1092)

# %%
_fft.fft_analysis.test_fftanal(plotit=False)
# Out:
# Using a periodic Hamming window function
# (SLDR~f**-1, PSLL=-42.7dB, ROV=50.0%, AF=1.000, PF=0.761, OC=0.234)
# Calculating spectra from 0.0 to 0.19999961853027345 s with 8 windows to yield a frequency resolution of 0.022500085831015898 KHz
# Using a periodic Hamming window function
# (SLDR~f**-1, PSLL=-42.7dB, ROV=50.0%, AF=1.000, PF=0.761, OC=0.234)
# using home-brew functions for spectra/coherence calculations

# %%
_fft.spectrogram.test_stft()
_fft.spectrogram.test_specgram()
# Out:
# Please give at least a time-vector [s] and a signal vector [a.u.]
# Using a periodic Rectangular window function
# (SLDR~f**-1, PSLL=-13.3dB, ROV=0.0%, AF=0, PF=1, OC=0)
# nWindows =  39
# C:\Users\gawe\Workshop\pyanalysis\FFT\spectrogram.py:250: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   _ax2.pcolormesh(twin, freq, 10*_np.log10(norm), shading='nearest', cmap=_plt.cm.rainbow) # , cmap=_plt.cm.hot)

# %%
_fft.spectrogram.test_dstft(nfft=512, nperseg=512//2, npts=2e3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_10324\2037834518.py in <module>
# ----> 1 _fft.spectrogram.test_dstft(nfft=512, nperseg=512//2, npts=2e3)
#
# AttributeError: module 'FFT.spectrogram' has no attribute 'test_dstft'

# %%
_fft.hilbert.test_hilbert(plotit=True, verbose=False)

# %%
_fft.laplace.test_laplace()

# %%
_fft.fft.test_fft_deriv(modified=True)
